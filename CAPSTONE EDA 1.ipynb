# %%
#importing all libraries and data needed for this analysis
import pandas as pd
import numpy as np
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
d1 = pd.read_excel('CapstoneData.xlsx')

# %%
d1.describe().round(2) #ststical summary of the data
# Out:
#           Year  AGRICULTURE     Crops  Livestock  Forestry  Fishing  INDUSTRY  \
# count    40.00        40.00     40.00      40.00     40.00    40.00     40.00
# mean   2000.50      7696.40   6815.02     592.94     79.30   209.15   8548.59
# std      11.69     10016.06   8876.28     725.04     96.26   351.54  11642.77
# min    1981.00        17.05     12.82       2.53      1.16     0.54     50.33
# 25%    1990.75       119.09     97.97      15.22      2.42     3.49    207.38
# 50%    2000.50      1761.92   1485.16     200.38     27.24    49.15   2358.62
# 75%    2010.25     13296.12  11884.14    1013.57    140.05   258.36  14833.10
# max    2020.00     37241.61  33177.54    2121.37    285.88  1657.91  43530.78
#
#        MiningQuarrying  CrudePetroleumNaturalGas  CoalMining  ...  RealEstate  \
# count            40.00                     40.00       40.00  ...       40.00
# mean           3566.91                   3509.61        4.47  ...     2504.12
# ...

# %%
d1.shape #this showa total number of rows and columns in the dataset
# Out:
# (40, 58)

# %%
d2=d1.set_index('Year')

# %%
d1.tail()
# Out:
#     Year  AGRICULTURE     Crops  Livestock  Forestry  Fishing  INDUSTRY  \
# 35  2016     21523.51  18883.08    1875.78    236.25   528.39  18641.17
# 36  2017     23952.55  21096.11    1974.45    257.21   624.79  25639.90
# 37  2018     27371.30  24207.80    2048.60    272.79   842.11  33218.33
# 38  2019     31904.14  28296.93    2108.95    285.88  1212.39  39879.69
# 39  2020     37241.61  33177.54    2121.37    284.79  1657.91  43530.78
#
#     MiningQuarrying  CrudePetroleumNaturalGas  CoalMining  ...  RealEstate  \
# 35          5469.55                   5367.32        8.49  ...     8340.43
# 36         10481.97                  10355.95        9.44  ...     8591.54
# 37         13648.66                  13423.87        9.78  ...     8632.82
# 38         12769.42                  12400.43       12.91  ...     8997.60
# 39         10851.77                  10195.63       11.48  ...     8678.13
#
#     ProfessionalScientificTechnicalServ.  AdministrativeSupportServices  \
# ...

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['NetTaxes'], color='royalblue')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='NetTaxes'>

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['PriceGDP'], color='darkred')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='PriceGDP'>

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['OtherServices'], color='purple')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='OtherServices'>

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['CoalMining'], color='purple')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='CoalMining'>

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['MiningQuarrying'], color='black')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='MiningQuarrying'>

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['INDUSTRY'], color='orange')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='INDUSTRY'>

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['Livestock'], color='green')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Livestock'>

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['PriceGDP'], color='blue')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='PriceGDP'>

# %%
plt.figure(figsize = (15,6))
sns.set(style="darkgrid")
sns.regplot(x=d1.Year, y=d1['AGRICULTURE'], color='orange')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='AGRICULTURE'>

# %%
plt.figure(figsize = (15,6))
sns.histplot(x=d1.Year, y=d1.PriceGDP)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='PriceGDP'>

# %%
plt.figure(figsize = (15,6))
sns.jointplot(x=d1.Year, y=d1['ProductGDP'],marker='+', s=50,color='green')

# %%
plt.figure(figsize = (6,10))
sns.jointplot(x=d1.Year, y=d1.NetTaxes,kind='hex',gridsize=30, color='skyblue')

# %%
plt.figure(figsize = (19,6))
sns.boxplot(x=d1.Year, y=d1.ProductGDP)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='ProductGDP'>

# %%
plt.figure(figsize = (19,6))
sns.violinplot(x=d1.AGRICULTURE, y=d1.MiningQuarrying)
# Out:
# <AxesSubplot:xlabel='AGRICULTURE', ylabel='MiningQuarrying'>

# %%
sns.lmplot(x = 'Year', y = 'AGRICULTURE', data = d1.reset_index(), hue='PriceGDP')

# %%
plt.figure(figsize=(12,6))
sns.heatmap(d2,cmap = 'coolwarm',linewidths=4)
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
plt.figure(figsize = (10,4))
sns.clustermap(d2,cmap = 'cool',linewidths =2)

# %%
plt.figure(figsize = (15,6))
sns.heatmap(d2, cmap = 'rainbow')
# Out:
# <AxesSubplot:ylabel='Year'>

# %%
sns.clustermap(d2, cmap = 'viridis')

# %%
sns.lmplot(data = d1, x = 'AGRICULTURE', y = 'PriceGDP', 
                  fit_reg = False, hue = 'ProductGDP')

# %%
sns.lineplot(data = d1, x = 'Year', y = 'PriceGDP', palette="rainbow")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='PriceGDP'>

# %%
plt.plot(d1.AGRICULTURE, d1.PriceGDP, d1.ProductGDP)

# %%
plt.scatter(d1.AGRICULTURE, d1.PriceGDP, d1.NetTaxes)

# %%
plt.figure(figsize = (10,6))
sns.violinplot(x = 'PriceGDP', data = d1, color='violet')
# Out:
# <AxesSubplot:xlabel='PriceGDP'>
